# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
t=np.linspace(0,2*np.pi,100)
x=t-np.sin(t)-np.pi
y=1-np.cos(t)
# 显示出坐标
plt.axis('equal')
plt.plot(x,y)

plt.show()
